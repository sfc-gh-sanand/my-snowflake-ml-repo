# %% [markdown]
# # Data Analysis & Tagging Verification
# This notebook analyzes table data and tests cost-tracking tags.

# %%
import snowflake.snowpark as snowpark
from snowflake.snowpark.functions import col

def main(session: snowpark.Session):
    # 1. Test Query with a Tag (Mauricio's Requirement)
    # Note: In current Snowflake, we set the tag at the session level
    session.sql("ALTER SESSION SET QUERY_TAG = 'project_vnext_verification'").collect()
    
    # 2. Simple Data Check
    df = session.table("INFORMATION_SCHEMA.TABLES").limit(5)
    
    return df
