# %% [markdown]
# # ML Training Notebook
# Current Version: **1.0.0**

# %%
import snowflake.snowpark as snowpark

def main(session: snowpark.Session):
    # To verify the update, change this string and redeploy
    deployment_version = 'v1_test'
    
    return f'Notebook deployed successfully! Version: {deployment_version}'
